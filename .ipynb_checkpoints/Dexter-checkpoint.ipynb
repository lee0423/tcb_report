# %%
import pandas as pd

# %%
pdf = pd.read_excel('/Users/liaoyi-ming/Desktop/tcb-metrics.xlsx',
                    sheet_name='Entity.Metrics',
                    index_col=None,)

pdf = pdf.rename(columns=pdf.iloc[2])

# %%
pdf = pdf.dropna(axis=0, how='all').drop(2, axis=0)

# %%
pdf = pdf.reset_index().drop("index", axis=1)

# %%
ddf = pd.DataFrame(pdf)

# %%
cols = ddf.columns

col_value = cols.get_loc("Value")

col_metric = cols.get_loc("MetricName")

col_entityname = cols.get_loc("EntityName")

col_eventtime = cols.get_loc("EventTime")

# %%
df1 = ddf.iloc[:, col_entityname]

df2 = ddf.iloc[:, col_metric]

df3 = ddf.iloc[:, col_eventtime]

df4 = ddf.iloc[:, col_value]

# %%
res1 = df1.join(df2)

# %%
res2 = res1.join(df3)

res3 = res2.join(df4)

res = res3

# %%
res.to_excel('/Users/liaoyi-ming/Desktop/test.xlsx', index=False)

# %%
res
# Out:
#              EntityName          EntityName          EntityName  \
# 0    Web-Portal_Node-01  Web-Portal_Node-01  Web-Portal_Node-01
# 1    Web-Portal_Node-01  Web-Portal_Node-01  Web-Portal_Node-01
# 2    Web-Portal_Node-01  Web-Portal_Node-01  Web-Portal_Node-01
# 3    Web-Portal_Node-01  Web-Portal_Node-01  Web-Portal_Node-01
# 4    Web-Portal_Node-01  Web-Portal_Node-01  Web-Portal_Node-01
# ..                  ...                 ...                 ...
# 115                 NaN                 NaN                 NaN
# 116                 NaN                 NaN                 NaN
# 117                 NaN                 NaN                 NaN
# 118                 NaN                 NaN                 NaN
# 119                 NaN                 NaN                 NaN
#
#              EntityName          EntityName          EntityName  \
# 0    Web-Portal_Node-01  Web-Portal_Node-01  Web-Portal_Node-01
# 1    Web-Portal_Node-01  Web-Portal_Node-01  Web-Portal_Node-01
# 2    Web-Portal_Node-01  Web-Portal_Node-01  Web-Portal_Node-01
# 3    Web-Portal_Node-01  Web-Portal_Node-01  Web-Portal_Node-01
# 4    Web-Portal_Node-01  Web-Portal_Node-01  Web-Portal_Node-01
# ..                  ...                 ...                 ...
# 115                 NaN                 NaN                 NaN
# 116                 NaN                 NaN                 NaN
# 117                 NaN                 NaN                 NaN
# 118                 NaN                 NaN                 NaN
# 119                 NaN                 NaN                 NaN
#
#                      EntityName                  EntityName  \
# 0            Web-Portal_Node-01          Web-Portal_Node-01
# 1            Web-Portal_Node-01          Web-Portal_Node-01
# 2            Web-Portal_Node-01          Web-Portal_Node-01
# 3            Web-Portal_Node-01          Web-Portal_Node-01
# 4            Web-Portal_Node-01          Web-Portal_Node-01
# ..                          ...                         ...
# 115  Inventory-Services_Node-01  Inventory-Services_Node-01
# 116  Inventory-Services_Node-01  Inventory-Services_Node-01
# 117  Inventory-Services_Node-01  Inventory-Services_Node-01
# 118  Inventory-Services_Node-01  Inventory-Services_Node-01
# 119  Inventory-Services_Node-01  Inventory-Services_Node-01
#
#                      EntityName                  EntityName  ... Value Value  \
# 0            Web-Portal_Node-01          Web-Portal_Node-01  ...   230     7
# 1            Web-Portal_Node-01          Web-Portal_Node-01  ...   266    29
# 2            Web-Portal_Node-01          Web-Portal_Node-01  ...   226    27
# 3            Web-Portal_Node-01          Web-Portal_Node-01  ...   241    29
# 4            Web-Portal_Node-01          Web-Portal_Node-01  ...    29     9
# ..                          ...                         ...  ...   ...   ...
# 115  Inventory-Services_Node-01  Inventory-Services_Node-01  ...   NaN   NaN
# 116  Inventory-Services_Node-01  Inventory-Services_Node-01  ...   NaN   NaN
# 117  Inventory-Services_Node-01  Inventory-Services_Node-01  ...   NaN   NaN
# 118  Inventory-Services_Node-01  Inventory-Services_Node-01  ...   NaN   NaN
# 119  Inventory-Services_Node-01  Inventory-Services_Node-01  ...   NaN   NaN
#
#     Value Value  Value  Value Value Value Value Value
# 0       0     8  18724   7852   200     1   200    59
# 1       0     8  18655   9318   200     1   200    58
# 2       0     8  18547  10768   200     1   200    58
# 3       0     8    561    384   200     1   200    57
# 4       0     8   1423     16   200     0   200    37
# ..    ...   ...    ...    ...   ...   ...   ...   ...
# 115   NaN   NaN    NaN    NaN   NaN   NaN   NaN   NaN
# 116   NaN   NaN    NaN    NaN   NaN   NaN   NaN   NaN
# 117   NaN   NaN    NaN    NaN   NaN   NaN   NaN   NaN
# 118   NaN   NaN    NaN    NaN   NaN   NaN   NaN   NaN
# 119   NaN   NaN    NaN    NaN   NaN   NaN   NaN   NaN
#
# [120 rows x 124 columns]

# %%
step_index = int(len(res.columns) / 4)

import os
 
dir = '/Users/liaoyi-ming/Desktop/tcb_report'
for f in os.listdir(dir):
    os.remove(os.path.join(dir, f))

print(step_index)

for i in range(0, step_index):
    rest = res.iloc[:,i::step_index].to_excel(f'/Users/liaoyi-ming/Desktop/tcb_report/{i+1}.xlsx', sheet_name=f'Sheet_name', index=False)
# Out:
# 31

# %%
import pandas as pd

import matplotlib.pyplot as plot

fd = pd.read_excel('/Users/liaoyi-ming/Desktop/tcb_report/1.xlsx')
fd = fd.pivot(index='EventTime', columns='EntityName', values='Value')
fd.plot( figsize=(15, 5))
# Out:
# <AxesSubplot: xlabel='EventTime'>

# %%
def report_group(dataframe):
    titles = ['EntityName', 'MetricName', 'EventTime', 'Value']
    new_group = []
    for col in dataframe.columns:
        if col in titles:
            new_group.append(col)
            
    return new_group

# %%
df = pd.read_excel('/Users/liaoyi-ming/Desktop/tcb-metrics.xlsx', 
                   sheet_name='Entity.Metrics',
                   usecols="C,E,H:I",
                   index_col=False)

pd.set_option('display.max_colwidth', None)

df = df.rename(columns=df.iloc[2])
df
# Out:
#              EntityName                  MetricName            EventTime  \
# 0                   NaN                         NaN                  NaN
# 1                   NaN                         NaN                  NaN
# 2            EntityName                  MetricName            EventTime
# 3    Web-Portal_Node-01  Average Response Time (ms)  2022-07-28 00:00:00
# 4    Web-Portal_Node-01  Average Response Time (ms)  2022-07-28 01:00:00
# ..                  ...                         ...                  ...
# 118                 NaN                         NaN                  NaN
# 119                 NaN                         NaN                  NaN
# 120                 NaN                         NaN                  NaN
# 121                 NaN                         NaN                  NaN
# 122                 NaN                         NaN                  NaN
#
#      Value
# 0      NaN
# 1      NaN
# 2    Value
# 3     1043
# 4     1102
# ..     ...
# 118    NaN
# 119    NaN
# 120    NaN
# 121    NaN
# 122    NaN
#
# [123 rows x 4 columns]

# %%
title = df.iloc[3,1]
print(title)
# Out:
# Average Response Time (ms)

# %%
df = df.dropna()
df = df.drop([2])

# %%
df
# Out:
#                     EntityName                  MetricName  \
# 3           Web-Portal_Node-01  Average Response Time (ms)
# 4           Web-Portal_Node-01  Average Response Time (ms)
# 5           Web-Portal_Node-01  Average Response Time (ms)
# 6           Web-Portal_Node-01  Average Response Time (ms)
# 7           Web-Portal_Node-01  Average Response Time (ms)
# 8           Web-Portal_Node-01  Average Response Time (ms)
# 9           Web-Portal_Node-01  Average Response Time (ms)
# 10          Web-Portal_Node-01  Average Response Time (ms)
# 11          Web-Portal_Node-01  Average Response Time (ms)
# 12          Web-Portal_Node-01  Average Response Time (ms)
# 13          Web-Portal_Node-01  Average Response Time (ms)
# 14          Web-Portal_Node-01  Average Response Time (ms)
# 15          Web-Portal_Node-01  Average Response Time (ms)
# 16          Web-Portal_Node-01  Average Response Time (ms)
# 17          Web-Portal_Node-01  Average Response Time (ms)
# 18          Web-Portal_Node-01  Average Response Time (ms)
# 19          Web-Portal_Node-01  Average Response Time (ms)
# 20    Enquiry-Services_Node-01  Average Response Time (ms)
# 21    Enquiry-Services_Node-01  Average Response Time (ms)
# 22        Api-Services_Node-01  Average Response Time (ms)
# 23        Api-Services_Node-01  Average Response Time (ms)
# 24        Api-Services_Node-01  Average Response Time (ms)
# 25        Api-Services_Node-01  Average Response Time (ms)
# 26  Insurance-Services_Node-01  Average Response Time (ms)
# 27  Insurance-Services_Node-01  Average Response Time (ms)
# 28  Insurance-Services_Node-01  Average Response Time (ms)
# 29  Insurance-Services_Node-01  Average Response Time (ms)
# 30  Insurance-Services_Node-01  Average Response Time (ms)
# 31  Insurance-Services_Node-01  Average Response Time (ms)
# 32  Insurance-Services_Node-01  Average Response Time (ms)
# 33  Inventory-Services_Node-01  Average Response Time (ms)
#
#               EventTime  Value
# 3   2022-07-28 00:00:00   1043
# 4   2022-07-28 01:00:00   1102
# 5   2022-07-28 02:00:00   1060
# 6   2022-07-28 03:00:00    540
# 7   2022-07-28 11:00:00   1821
# 8   2022-07-28 12:00:00  10864
# 9   2022-07-28 13:00:00  10280
# 10  2022-07-28 14:00:00   1355
# 11  2022-07-28 15:00:00    943
# 12  2022-07-28 16:00:00   1275
# 13  2022-07-28 17:00:00   3295
# 14  2022-07-28 18:00:00    872
# 15  2022-07-28 19:00:00   1072
# 16  2022-07-28 20:00:00   1052
# 17  2022-07-28 21:00:00   1058
# 18  2022-07-28 22:00:00   1125
# 19  2022-07-28 23:00:00    884
# 20  2022-07-28 11:00:00   1168
# 21  2022-07-28 12:00:00   1165
# 22  2022-07-28 11:00:00   2829
# 23  2022-07-28 12:00:00   1301
# 24  2022-07-28 13:00:00    157
# 25  2022-07-28 14:00:00    139
# 26  2022-07-28 11:00:00   2798
# 27  2022-07-28 12:00:00   4446
# 28  2022-07-28 13:00:00   5860
# 29  2022-07-28 14:00:00   4877
# 30  2022-07-28 15:00:00   3310
# 31  2022-07-28 16:00:00   4311
# 32  2022-07-28 17:00:00   8045
# 33  2022-07-28 11:00:00   2074

# %%
df['Value'] = df['Value'].astype('int16')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 31 entries, 3 to 33
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   EntityName  31 non-null     object
#  1   MetricName  31 non-null     object
#  2   EventTime   31 non-null     object
#  3   Value       31 non-null     object
# dtypes: object(4)
# memory usage: 1.2+ KB

# %%
df_group = df.groupby('EntityName')

df_group.head()
# Out:
#                     EntityName                  MetricName  \
# 3           Web-Portal_Node-01  Average Response Time (ms)
# 4           Web-Portal_Node-01  Average Response Time (ms)
# 5           Web-Portal_Node-01  Average Response Time (ms)
# 6           Web-Portal_Node-01  Average Response Time (ms)
# 7           Web-Portal_Node-01  Average Response Time (ms)
# 20    Enquiry-Services_Node-01  Average Response Time (ms)
# 21    Enquiry-Services_Node-01  Average Response Time (ms)
# 22        Api-Services_Node-01  Average Response Time (ms)
# 23        Api-Services_Node-01  Average Response Time (ms)
# 24        Api-Services_Node-01  Average Response Time (ms)
# 25        Api-Services_Node-01  Average Response Time (ms)
# 26  Insurance-Services_Node-01  Average Response Time (ms)
# 27  Insurance-Services_Node-01  Average Response Time (ms)
# 28  Insurance-Services_Node-01  Average Response Time (ms)
# 29  Insurance-Services_Node-01  Average Response Time (ms)
# 30  Insurance-Services_Node-01  Average Response Time (ms)
# 33  Inventory-Services_Node-01  Average Response Time (ms)
#
#               EventTime Value
# 3   2022-07-28 00:00:00  1043
# 4   2022-07-28 01:00:00  1102
# 5   2022-07-28 02:00:00  1060
# 6   2022-07-28 03:00:00   540
# 7   2022-07-28 11:00:00  1821
# 20  2022-07-28 11:00:00  1168
# 21  2022-07-28 12:00:00  1165
# 22  2022-07-28 11:00:00  2829
# 23  2022-07-28 12:00:00  1301
# 24  2022-07-28 13:00:00   157
# 25  2022-07-28 14:00:00   139
# 26  2022-07-28 11:00:00  2798
# 27  2022-07-28 12:00:00  4446
# 28  2022-07-28 13:00:00  5860
# 29  2022-07-28 14:00:00  4877
# 30  2022-07-28 15:00:00  3310
# 33  2022-07-28 11:00:00  2074

# %%
import matplotlib.pyplot as plt
import seaborn as sns


df['EventTime']=pd.to_datetime(df['EventTime'])
df.plot(x='EntityName', y='Value',figsize=(10,8), title=title, kind='line')
# Out:
# <AxesSubplot: title={'center': 'Average Response Time (ms)'}, xlabel='EntityName'>

# %%
df.stack().head()
# Out:
# 3  EntityName            Web-Portal_Node-01
#    MetricName    Average Response Time (ms)
#    EventTime            2022-07-28 00:00:00
#    Value                               1043
# 4  EntityName            Web-Portal_Node-01
# dtype: object
